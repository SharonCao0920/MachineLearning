# %% [markdown]
# # **CS550 Week 3 HW2 (Q2)**

# %% [markdown]
# ### **Get Data and Plot in Graph**

# %%
import matplotlib.pyplot as plt

x = [1.5,1,2,5,3.5,4.5,2.5]
y = [1,2,3.5,6,4.,5,4.5]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### **Fit data and Show Analysis**

# %%
from sklearn.cluster import KMeans

data = list(zip(x, y))
inertias = []

for i in range(1,len(x)+1):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,len(x)+1), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ### **Show Result for Cluster=2**

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(data)

plt.scatter(x, y, c=kmeans.labels_)
plt.show()

# %% [markdown]
# # **Optional HW (Q40)**

# %%
import matplotlib.pyplot as plt

x = [1,2,2,2,3,3,4,5,4,5,5,6,8,9,8,9,9,10]
y = [1,4,1,2,1,3,6,5,7,7,6,5,8,8,9,9,10,10]

from sklearn.cluster import KMeans
data = list(zip(x, y))

kmeans = KMeans(n_clusters=2)
kmeans.fit(data)

plt.scatter(x, y, c=kmeans.labels_)
plt.title("K=2")
plt.show()

kmeans = KMeans(n_clusters=3)
plt.title("K=3")
kmeans.fit(data)

plt.scatter(x, y, c=kmeans.labels_)
plt.show()

# %%
from sklearn.cluster import KMeans

data = list(zip(x, y))
inertias = []

for i in range(1,len(x)+1):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,len(x)+1), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
